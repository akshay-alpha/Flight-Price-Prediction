# %% [markdown]
# ## FLIGHT PRICE PREDICTION
# Anyone who has booked a flight ticket knows how unexpectedly the prices vary. The cheapest available ticket on a given flight gets more and less expensive over time. This usually happens as an attempt to maximize revenue based on -
#
# Time of purchase patterns (making sure last-minute purchases are expensive)
# Keeping the flight as full as they want it (raising prices on a flight which is filling up in order to reduce sales and hold back inventory for those expensive last-minute expensive purchases) So, you have to work on a project where you collect data of flight fares with other features and work to make a model to predict fares of flights.
# ## STEPS
# ## 1. Data Collection
# You have to scrape at least 1500 rows of data. You can scrape more data as well, it’s up to you, More the data better the model In this section you have to scrape the data of flights from different websites (yatra.com, skyscanner.com, official websites of airlines, etc). The number of columns for data doesn’t have limit, it’s up to you and your creativity. Generally, these columns areairline name, date of journey, source, destination, route, departure time, arrival time, duration, total stops and the target variable price. You can make changes to it, you can add or you can remove some columns, it completely depends on the website from which you are fetching the data.
#
# ##### COLUMNS:
# ##### airline name, date of journey, source, destination, route, departure time, arrival time, duration, total stops and the target variable price

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time

import warnings
warnings.filterwarnings('ignore')

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=22%2F03%2F2022&hb=&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647710414601&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length=l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=25%2F03%2F2022&hb=&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647711384279&viewName=normal')
time.sleep(2)

# %%
for i in range(1000):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length=l2
except:
    Airline_name.append('Nan')
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=26%2F03%2F2022&hb=&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647711384279&viewName=normal')
time.sleep(2)

# %%
for i in range(500):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=23%2F03%2F2022&hb=&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647711384279&viewName=normal')
time.sleep(2)

# %%
for i in range(500):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l1-l2-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=24%2F03%2F2022&hb=&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647711384279&viewName=normal')
time.sleep(2)

# %%
for i in range(100):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l5 = len(Airline_name)-l1-l2-l3-l4
    length=l5
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (165, 165, 165, 165, 165, 165, 165, 165, 165, 165, 165)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=02%2F04%2F2022&hb=&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647711384279&viewName=normal')
time.sleep(2)

# %%
for i in range(500):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l6 = len(Airline_name)-l1-l2-l3-l4-l5
    length=l6
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time), len(source),len(destination),len(duration),len(price)
# Out:
# (200, 200, 200, 200, 200, 200, 200, 200, 200)

# %%
df1 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df1
# Out:
#     Airline Name Departure Date Arrival Time Departure Time     Source  \
# 0       Go First    Wed, 23 Mar        17:00          15:00  New Delhi
# 1      Air India    Wed, 23 Mar        20:00          18:00  New Delhi
# 2         IndiGo    Wed, 23 Mar        04:10          02:00  New Delhi
# 3       Go First    Wed, 23 Mar        13:25          11:15  New Delhi
# 4         IndiGo    Wed, 23 Mar        19:25          17:15  New Delhi
# ..           ...            ...          ...            ...        ...
# 195      Vistara                       09:45          07:30  New Delhi
# 196     Go First                       10:15          08:00  New Delhi
# 197       IndiGo                       11:00          08:45  New Delhi
# 198    Air India                       11:15          09:00  New Delhi
# 199      Vistara                       12:35          10:20  New Delhi
#
#     Destination Duration Total Stops  Price
# 0        Mumbai   2h 00m    Non Stop  7,320
# ...

# %% [markdown]
# ## Delhi - Banglore

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=02%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647718969898&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=04%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647718969898&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length=l2
except:
    Airline_name.append('Nan')
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=06%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647718969898&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=23%2F03%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1647718969898&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l1-l2-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df2 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df2
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0      Air Asia                          10:40          08:10  New Delhi
# 1      Go First                          08:35          06:00  New Delhi
# 2        IndiGo                          11:00          08:20  New Delhi
# 3      Go First                          23:10          20:30  New Delhi
# 4       Vistara                          23:20          20:40  New Delhi
# ..          ...            ...             ...            ...        ...
# 95     Go First    Wed, 23 Mar           07:40          02:00  New Delhi
# 96     SpiceJet    Wed, 23 Mar           22:45          17:00  New Delhi
# 97     Go First    Wed, 23 Mar           14:55          09:00  New Delhi
# 98     Go First    Wed, 23 Mar           11:50          05:50  New Delhi
# 99     Go First    Wed, 23 Mar  00:20\n+ 1 day          18:20  New Delhi
#
#    Destination Duration Total Stops  Price
# 0    Bangalore   2h 30m    Non Stop  8,160
# ...

# %% [markdown]
# ## Mumbai-Bangalore

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=28%2F03%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=572111730468&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=30%2F03%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=572111730468&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length=l2
except:
    Airline_name.append('Nan')
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=02%2F04%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=572111730468&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=07%2F04%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=572111730468&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df3 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df3
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time  Source  \
# 0        IndiGo                 00:10\n+ 1 day          22:40  Mumbai
# 1        IndiGo                          07:40          06:05  Mumbai
# 2      Go First                          07:45          06:10  Mumbai
# 3        IndiGo                          13:20          11:45  Mumbai
# 4      Air Asia                          23:35          22:00  Mumbai
# ..          ...            ...             ...            ...     ...
# 95      Vistara                          20:55          19:10  Mumbai
# 96      Vistara                          07:50          06:00  Mumbai
# 97      Vistara                          08:50          07:00  Mumbai
# 98       IndiGo                          23:40          19:55  Mumbai
# 99       IndiGo                          10:35          06:05  Mumbai
#
#    Destination Duration Total Stops  Price
# 0    Bangalore   1h 30m    Non Stop  6,258
# ...

# %% [markdown]
# ##  Kolkata - Chennai

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=26%2F03%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=195367049249&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=09%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=195367049249&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)
    length= len(Airline_name)-l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=14%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=195367049249&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 50, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=19%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=195367049249&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df4 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df4
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time   Source  \
# 0      SpiceJet    Wed, 23 Mar           23:55          21:40  Kolkata
# 1        IndiGo    Wed, 23 Mar           19:00          12:55  Kolkata
# 2        IndiGo    Wed, 23 Mar           21:05          14:50  Kolkata
# 3        IndiGo    Wed, 23 Mar           21:05          11:25  Kolkata
# 4      SpiceJet    Wed, 23 Mar  07:00\n+ 1 day          20:30  Kolkata
# ..          ...            ...             ...            ...      ...
# 95       IndiGo                 08:00\n+ 1 day          23:10  Kolkata
# 96       IndiGo                          15:55          06:45  Kolkata
# 97       IndiGo                          16:25          07:15  Kolkata
# 98       IndiGo                          15:10          05:55  Kolkata
# 99       IndiGo                          23:35          13:20  Kolkata
#
#    Destination Duration Total Stops  Price
# 0      Chennai   2h 15m    Non Stop  7,854
# ...

# %% [markdown]
# ## Kochi - Pune

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=PNQ&destinationCountry=IN&flexi=0&flight_depart_date=26%2F03%2F2022&hb=0&noOfSegments=1&origin=COK&originCountry=IN&type=O&unique=1224358165074&version=1.1&viewName=normal')
time.sleep(2)

# %%
for i in range(1000):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=17%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=195367049249&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (47, 47, 47, 47, 47, 47, 47, 47, 47, 47, 47)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=21%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=195367049249&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=23%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=195367049249&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (97, 97, 97, 97, 97, 97, 97, 97, 97, 97, 97)

# %%
df5 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df5
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time   Source  \
# 0        IndiGo    Wed, 23 Mar  03:35\n+ 1 day          19:00    Kochi
# 1        IndiGo    Wed, 23 Mar  05:05\n+ 1 day          19:00    Kochi
# 2        IndiGo    Wed, 23 Mar           02:10          00:25    Kochi
# 3        IndiGo    Wed, 23 Mar  00:05\n+ 1 day          15:05    Kochi
# 4        IndiGo    Wed, 23 Mar  00:05\n+ 1 day          13:45    Kochi
# ..          ...            ...             ...            ...      ...
# 92       IndiGo                          12:10          05:40  Kolkata
# 93       IndiGo                          12:10          04:30  Kolkata
# 94       IndiGo                          09:05          04:30  Kolkata
# 95       IndiGo                          10:50          05:40  Kolkata
# 96       IndiGo                          10:50          04:30  Kolkata
#
#    Destination Duration Total Stops  Price
# 0         Pune   8h 35m      1 Stop  7,197
# ...

# %% [markdown]
# ## Hydrabad-Ahemdabad

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=AMD&destinationCountry=IN&flexi=0&flight_depart_date=23%2F04%2F2022&hb=0&noOfSegments=1&origin=HYD&originCountry=IN&type=O&unique=819888518030&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=AMD&destinationCountry=IN&flexi=0&flight_depart_date=12%2F04%2F2022&hb=0&noOfSegments=1&origin=HYD&originCountry=IN&type=O&unique=819888518030&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=AMD&destinationCountry=IN&flexi=0&flight_depart_date=07%2F04%2F2022&hb=0&noOfSegments=1&origin=HYD&originCountry=IN&type=O&unique=819888518030&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=AMD&destinationCountry=IN&flexi=0&flight_depart_date=19%2F04%2F2022&hb=0&noOfSegments=1&origin=HYD&originCountry=IN&type=O&unique=819888518030&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df6 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df6
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0      Go First                          07:30          05:40  Hyderabad
# 1        IndiGo                          08:15          06:25  Hyderabad
# 2        IndiGo                          23:45          22:05  Hyderabad
# 3        IndiGo                          22:15          20:40  Hyderabad
# 4     Air India                 20:00\n+ 1 day          22:15  Hyderabad
# ..          ...            ...             ...            ...        ...
# 95       IndiGo                 01:50\n+ 1 day          20:05  Hyderabad
# 96       IndiGo                 03:50\n+ 1 day          20:30  Hyderabad
# 97       IndiGo                 06:20\n+ 1 day          23:15  Hyderabad
# 98       IndiGo                 06:05\n+ 1 day          22:15  Hyderabad
# 99       IndiGo                 01:45\n+ 1 day          17:50  Hyderabad
#
#    Destination Duration Total Stops  Price
# 0    Ahmedabad   1h 50m    Non Stop  4,452
# ...

# %% [markdown]
# ## Chennai - Mumbai

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=30%2F03%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=788143755506&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=02%2F04%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=788143755506&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=23%2F03%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=788143755506&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=26%2F03%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=788143755506&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df7 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df7
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time   Source  \
# 0        IndiGo                          09:55          08:10  Chennai
# 1        IndiGo                          05:55          04:05  Chennai
# 2      Go First                          06:50          05:00  Chennai
# 3        IndiGo                          13:40          11:50  Chennai
# 4        IndiGo                          14:45          12:55  Chennai
# ..          ...            ...             ...            ...      ...
# 95       IndiGo    Wed, 23 Mar           23:25          17:05  Chennai
# 96       IndiGo    Wed, 23 Mar           23:15          16:30  Chennai
# 97       IndiGo    Wed, 23 Mar           21:35          14:30  Chennai
# 98       IndiGo    Wed, 23 Mar  00:35\n+ 1 day          16:30  Chennai
# 99       IndiGo    Wed, 23 Mar           21:35          13:05  Chennai
#
#    Destination Duration Total Stops  Price
# 0       Mumbai   1h 45m    Non Stop  7,247
# ...

# %% [markdown]
# ## Kochi - Pune

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=PNQ&destinationCountry=IN&flexi=0&flight_depart_date=28%2F03%2F2022&hb=0&noOfSegments=1&origin=COK&originCountry=IN&type=O&unique=1486404196611&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=PNQ&destinationCountry=IN&flexi=0&flight_depart_date=05%2F04%2F2022&hb=0&noOfSegments=1&origin=COK&originCountry=IN&type=O&unique=1486404196611&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=PNQ&destinationCountry=IN&flexi=0&flight_depart_date=11%2F04%2F2022&hb=0&noOfSegments=1&origin=COK&originCountry=IN&type=O&unique=1486404196611&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=PNQ&destinationCountry=IN&flexi=0&flight_depart_date=17%2F04%2F2022&hb=0&noOfSegments=1&origin=COK&originCountry=IN&type=O&unique=1486404196611&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df8 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df8
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time Source  \
# 0        IndiGo                          15:05          11:30  Kochi
# 1        IndiGo                          17:15          12:30  Kochi
# 2        IndiGo                          15:05          09:40  Kochi
# 3        IndiGo                 00:20\n+ 1 day          18:55  Kochi
# 4        IndiGo                          23:30          17:35  Kochi
# ..          ...            ...             ...            ...    ...
# 95      Vistara                 12:35\n+ 1 day          09:15  Kochi
# 96    Air India                 11:35\n+ 1 day          08:05  Kochi
# 97       IndiGo                 00:20\n+ 1 day          15:00  Kochi
# 98       IndiGo                 06:50\n+ 1 day          21:15  Kochi
# 99       IndiGo                 01:35\n+ 1 day          23:50  Kochi
#
#    Destination Duration Total Stops   Price
# 0         Pune   3h 35m      1 Stop   7,197
# 1         Pune   4h 45m      1 Stop   7,197
# ...

# %% [markdown]
# ## New Delhi-Banglore

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=01%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=323410524515&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=04%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=323410524515&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=13%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=323410524515&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=21%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=323410524515&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df9 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df9
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0      Air Asia                          10:40          08:10  New Delhi
# 1        IndiGo                          19:55          17:25  New Delhi
# 2      Go First                          08:35          06:00  New Delhi
# 3        IndiGo                          15:35          13:00  New Delhi
# 4        IndiGo                          11:00          08:20  New Delhi
# ..          ...            ...             ...            ...        ...
# 95      Vistara                          22:40          19:50  New Delhi
# 96       IndiGo                          23:00          20:10  New Delhi
# 97    Air India                 00:05\n+ 1 day          21:15  New Delhi
# 98       IndiGo                 01:45\n+ 1 day          22:55  New Delhi
# 99       IndiGo                          09:50          06:55  New Delhi
#
#    Destination Duration Total Stops  Price
# 0    Bangalore   2h 30m    Non Stop  8,160
# ...

# %% [markdown]
# ## Chennai-Mumbai

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=31%2F03%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=464721648785&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=03%2F04%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=464721648785&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=10%2F04%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=464721648785&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=16%2F04%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=464721648785&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df10 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df10
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time   Source  \
# 0        IndiGo                          05:55          04:05  Chennai
# 1      Go First                          06:50          05:00  Chennai
# 2        IndiGo                          13:40          11:50  Chennai
# 3        IndiGo                          14:45          12:55  Chennai
# 4      SpiceJet                          08:20          06:25  Chennai
# ..          ...            ...             ...            ...      ...
# 95       IndiGo                          19:55          18:00  Chennai
# 96       IndiGo                 00:40\n+ 1 day          20:05  Chennai
# 97     SpiceJet                          20:10          07:50  Chennai
# 98     SpiceJet                 08:10\n+ 1 day          07:50  Chennai
# 99       IndiGo                          20:35          17:00  Chennai
#
#    Destination Duration Total Stops  Price
# 0       Mumbai   1h 50m    Non Stop  7,247
# ...

# %% [markdown]
# ## Ahmedabad -Bangalore

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=29%2F03%2F2022&hb=0&noOfSegments=1&origin=AMD&originCountry=IN&type=O&unique=1106657968818&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=07%2F04%2F2022&hb=0&noOfSegments=1&origin=AMD&originCountry=IN&type=O&unique=1106657968818&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=12%2F04%2F2022&hb=0&noOfSegments=1&origin=AMD&originCountry=IN&type=O&unique=1106657968818&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=22%2F04%2F2022&hb=0&noOfSegments=1&origin=AMD&originCountry=IN&type=O&unique=1106657968818&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df11 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df11
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0        IndiGo                          09:45          07:40  Ahmedabad
# 1      Go First                          10:10          08:05  Ahmedabad
# 2        IndiGo                          23:25          21:20  Ahmedabad
# 3        IndiGo                 01:40\n+ 1 day          23:35  Ahmedabad
# 4        IndiGo                          06:50          04:30  Ahmedabad
# ..          ...            ...             ...            ...        ...
# 95     Go First                 02:55\n+ 1 day          21:15  Ahmedabad
# 96       IndiGo                          11:35          06:40  Ahmedabad
# 97       IndiGo                 07:40\n+ 1 day          23:25  Ahmedabad
# 98       IndiGo                 06:05\n+ 1 day          20:50  Ahmedabad
# 99       IndiGo                          09:30          04:30  Ahmedabad
#
#    Destination Duration Total Stops  Price
# 0    Bangalore   2h 05m    Non Stop  7,266
# ...

# %% [markdown]
# ## Delhi-Kolkata

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=26%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=294701425513&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=15%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=294701425513&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=08%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=294701425513&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=03%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=294701425513&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df12 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df12
# Out:
#    Airline Name Departure Date Arrival Time Departure Time     Source  \
# 0        IndiGo                       07:50          06:05  New Delhi
# 1      SpiceJet                       09:05          07:05  New Delhi
# 2        IndiGo                       05:05          03:00  New Delhi
# 3      Go First                       07:50          05:45  New Delhi
# 4        IndiGo                       10:45          08:40  New Delhi
# ..          ...            ...          ...            ...        ...
# 95     Air Asia                       23:00          20:40  New Delhi
# 96     SpiceJet                       21:55          19:30  New Delhi
# 97       IndiGo                       18:50          14:00  New Delhi
# 98       IndiGo                       20:55          15:55  New Delhi
# 99       IndiGo                       10:30          05:15  New Delhi
#
#    Destination Duration Total Stops  Price
# 0      Kolkata   1h 45m    Non Stop  4,800
# ...

# %% [markdown]
# ## Bangalore -  New Delhi

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=23%2F03%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=71830440647&version=1.5&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=27%2F03%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=71830440647&version=1.5&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=29%2F03%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=71830440647&version=1.5&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=09%2F04%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=71830440647&version=1.5&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
df13 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df13
# Out:
#    Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0      SpiceJet    Thu, 24 Mar  00:45\n+ 1 day          22:05  Bangalore
# 1        IndiGo    Thu, 24 Mar           12:15          09:30  Bangalore
# 2      SpiceJet    Thu, 24 Mar           21:50          19:05  Bangalore
# 3      Air Asia    Thu, 24 Mar           03:20          00:30  Bangalore
# 4        IndiGo    Thu, 24 Mar           09:30          06:40  Bangalore
# ..          ...            ...             ...            ...        ...
# 95     Air Asia                          22:55          15:15  Bangalore
# 96       IndiGo                          23:25          15:35  Bangalore
# 97    Air India                 00:05\n+ 1 day          21:00  Bangalore
# 98      Vistara                          23:45          21:10  Bangalore
# 99       IndiGo                          22:00          19:15  Bangalore
#
#    Destination Duration Total Stops  Price
# 0    New Delhi   2h 40m    Non Stop  8,223
# ...

# %% [markdown]
# ## Chennai - Kolkata

# %%
Airline_name = []
Date = []
arrival_time=[]
dep_time = []
source = []
destination=[]
duration = []
total_stops = []
price=[]

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=20%2F04%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=1056541118495&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l1 = len(Airline_name)
    length= l1
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=24%2F04%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=1056541118495&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div/div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l2 = len(Airline_name)-l1
    length= l2
except:
    Airline_name.append('Nan')
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
except:
    Date.append('Nan')

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=12%2F04%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=1056541118495&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[1]/div/div[2]/span')
    for i in tag:
        Airline_name.append(i.text)
        
    l3 = len(Airline_name)-l2-l1
    length=l3
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')
    
len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=18%2F04%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=1056541118495&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l4 = len(Airline_name)-l2-l1-l3
    length=l4
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %%
#loading web driver
driver = webdriver.Chrome(r"C:/Users/atoranga/Documents/chromedriver.exe") 
driver.get('https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=28%2F04%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=1056541118495&version=1.1&viewName=normal')
time.sleep(2)

# %%
#airline tags
try:
    tag = driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')
    for i in tag:
        Airline_name.append(i.text)
        
    l5 = len(Airline_name)-l2-l1-l3-l4
    length=l5
except:
    Airline_name.append('Nan')
    
    
#date of journey
try:
    tag = driver.find_elements_by_xpath('/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]')
    while length>0:
        for i in tag:
            Date.append(i.text)
            length-=1
        
except:
    pass 

#departure time
try:
    tag = driver.find_elements_by_xpath('//div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/div')
    for i in tag:
        dep_time.append(i.text)
except:
    dep_time.append('Nan')

#arrival time
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[1]')
    for i in tag:
        arrival_time.append(i.text)
except:
    arrival_time.append('Nan')


#source
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[1]/p')
    for i in tag:
        source.append(i.text)
except:
    source.append('Nan')
    
#destination
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[1]/div/div[3]/p[2]')
    for i in tag:
        destination.append(i.text)
except:
    destination.append('Nan')    

#total stops
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/span')
    for i in tag:
        total_stops.append(i.text)
except:
    total_stops.append('Nan')

#Price
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[4]/div/div[1]/div/label/div/div[2]')
    for i in tag:
        price.append(i.text)
        
except:
    price.append('Nan')
    
try:
    tag = driver.find_elements_by_xpath('//div/div/div[2]/div[2]/div/div/div/div/div[2]/div/p')
    for i in tag:
        duration.append(i.text)
        
except:
    price.append('Nan')

len(total_stops),len(Airline_name),len(Date),len(arrival_time),len(dep_time),len(dep_time), len(source),len(destination),len(duration),len(total_stops),len(price)
# Out:
# (125, 125, 125, 125, 125, 125, 125, 125, 125, 125, 125)

# %%
df14 = pd.DataFrame({'Airline Name':Airline_name, 'Departure Date':Date,'Arrival Time':arrival_time,'Departure Time':dep_time, 'Source':source, 'Destination':destination,'Duration':duration,'Total Stops':total_stops,'Price':price})
df14
# Out:
#     Airline Name Departure Date Arrival Time Departure Time   Source  \
# 0       Go First                       13:30          11:15  Chennai
# 1       SpiceJet                       14:25          12:10  Chennai
# 2       SpiceJet                       20:50          18:30  Chennai
# 3       SpiceJet                       09:15          06:40  Chennai
# 4         IndiGo                       16:00          13:25  Chennai
# ..           ...            ...          ...            ...      ...
# 120       IndiGo                       17:00          10:35  Chennai
# 121       IndiGo                       14:20          07:45  Chennai
# 122       IndiGo                       18:00          11:20  Chennai
# 123       IndiGo                       20:35          13:00  Chennai
# 124       IndiGo                       16:05          07:45  Chennai
#
#     Destination Duration Total Stops  Price
# 0       Kolkata   2h 15m    Non Stop  5,041
# 1       Kolkata   2h 15m    Non Stop  5,041
# ...

# %% [markdown]
# ## Let us combine all the dataframes we have scraped into one.

# %%
Flight_details = pd.concat((df1,df2,df3,df4,df5,df6,df7,df8,df9,df9,df10,df11,df12,df13,df14), ignore_index=True)
Flight_details
# Out:
#      Airline Name Departure Date Arrival Time Departure Time     Source  \
# 0        Go First    Wed, 23 Mar        17:00          15:00  New Delhi
# 1       Air India    Wed, 23 Mar        20:00          18:00  New Delhi
# 2          IndiGo    Wed, 23 Mar        04:10          02:00  New Delhi
# 3        Go First    Wed, 23 Mar        13:25          11:15  New Delhi
# 4          IndiGo    Wed, 23 Mar        19:25          17:15  New Delhi
# ...           ...            ...          ...            ...        ...
# 1617       IndiGo                       17:00          10:35    Chennai
# 1618       IndiGo                       14:20          07:45    Chennai
# 1619       IndiGo                       18:00          11:20    Chennai
# 1620       IndiGo                       20:35          13:00    Chennai
# 1621       IndiGo                       16:05          07:45    Chennai
#
#      Destination Duration Total Stops  Price
# 0         Mumbai   2h 00m    Non Stop  7,320
# ...

# %%
#shuffling all the data and resetting the index

Flight_details = Flight_details.sample(frac=1).reset_index(drop=True)
Flight_details
# Out:
#      Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0          IndiGo                          13:20          04:30  Ahmedabad
# 1        Go First    Wed, 23 Mar           16:05          14:00  New Delhi
# 2       Air India                          19:15          17:00    Kolkata
# 3          IndiGo                 01:50\n+ 1 day          17:45  Hyderabad
# 4        Air Asia                          23:25          21:00    Kolkata
# ...           ...            ...             ...            ...        ...
# 1617    Air India    Wed, 23 Mar  07:05\n+ 1 day          20:10      Kochi
# 1618      Vistara                          19:15          17:30     Mumbai
# 1619       IndiGo                          20:55          15:55  New Delhi
# 1620      Vistara    Wed, 23 Mar           07:55          05:45  New Delhi
# 1621    Air India                          18:20          16:40     Mumbai
#
#      Destination Duration Total Stops   Price
# ...

# %%
# converting the dataframe to csv file

Flight_details.to_csv('Flight_details.csv', index=False)

# %%
Flight_details
# Out:
#      Airline Name Departure Date    Arrival Time Departure Time     Source  \
# 0          IndiGo                          13:20          04:30  Ahmedabad
# 1        Go First    Wed, 23 Mar           16:05          14:00  New Delhi
# 2       Air India                          19:15          17:00    Kolkata
# 3          IndiGo                 01:50\n+ 1 day          17:45  Hyderabad
# 4        Air Asia                          23:25          21:00    Kolkata
# ...           ...            ...             ...            ...        ...
# 1617    Air India    Wed, 23 Mar  07:05\n+ 1 day          20:10      Kochi
# 1618      Vistara                          19:15          17:30     Mumbai
# 1619       IndiGo                          20:55          15:55  New Delhi
# 1620      Vistara    Wed, 23 Mar           07:55          05:45  New Delhi
# 1621    Air India                          18:20          16:40     Mumbai
#
#      Destination Duration Total Stops   Price
# ...
